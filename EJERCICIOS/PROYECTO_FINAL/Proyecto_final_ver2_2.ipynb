# %% [markdown]
# <a href="https://colab.research.google.com/github/ferochon/Python/blob/main/EJERCICIOS/PROYECTO_FINAL/Proyecto_final_ver2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
plantilla1='''


      ( )   ¡ups!
     //.\\\                                                                                                                                                   
     "|||"
   ___=_=___      '''


plantilla2='''
          
                          ¡vamos tu puedes! inentalo de nuevo  
                  ( )
                 //.\\\   
   _________     "|||"
  |_________|     = =  '''


plantilla3='''
          
  |   
  |                     ¡rayos! volviste a fallar                                                                                                                                   
  |               ( )
  |              //.\\\ 
  |_________     "|||"
  |_________|     = =   '''


plantilla4='''
  __________        
  |   
  |                   ¡oh, ho!                                                                                                                                  
  |              ( )
  |             //.\\\ 
  |_________    "|||"  
  |_________|    = =   '''


plantilla5='''
  __________ 
  |    |   
  |   (_)             ¡esto se pone interesante!
  |              ( )
  |             //.\\\ 
  |_________    "|||"  
  |_________|    = =   '''  


plantilla6='''
  __________ 
  |    |
  |   ( )       ¡qué meyo!   
  |  //.\\\                                                                                                                                                   
  |  "|||"
  |___=_=___
  |_________|  '''


plantilla7='''
  __________ 
  |    |
  |   ( )      ¡auch!
  |  //.\\\                                                                                                                                                   
  |  "|||"
  |   = =
  |_________  '''




palabra_secreta= 'perro'
letras_ingresadas=['_','_','_','_','_']    #para meter las letras ingresadas en una lista
lista_palabra_secreta=[] #crear una lista vacia para meter la palabra secreta
lista_palabra_secreta.extend(palabra_secreta)   #meter la palabra secreta en la lista
ahorcado={1:plantilla1, 2:plantilla2, 3:plantilla3, 4:plantilla4, 5:plantilla5, 6:plantilla6, 7:plantilla7}
entrada=1
m=int(0)   #registro de intentos

longitud=len(lista_palabra_secreta)
vidas=int(7)
print(f'''
{30*'= '}
Bien venido al juego del ahorcado:
{30*'= '}''')
print(f'''
Adivina la palabra secreta:''')
print(f'''{"__ "  * len(palabra_secreta)} ({len(palabra_secreta)} letras)''')
while longitud>0 and vidas >0:                  #while len(lista_palabra_secreta)>0 and vidas >0:
  
  print(f'''
Te quedan {vidas} vidas.
        ''')
  print(f'''------------------------------------------------
  ''')
  
  letra=input(f'''Ingresa una letra (en minúscula): ''')
  letra=letra.lower()
  print(f' ')
  if letra in letras_ingresadas:
    print('Esa letra ya la adivinaste (este intento no contará')
  else:
#    letras_ingresadas.append(letra)  # la letra ingresada y validada entra en una lista
#    print(letras_ingresadas)
    m=m+1
    if(letra in lista_palabra_secreta):
      
      print(f'''La letra "{letra}"" sí está en la palabra secreta y va colocada así:
      ''' )
      
      while letra in lista_palabra_secreta:
        
        indice=int(lista_palabra_secreta.index(letra))
        lista_palabra_secreta[indice]='_'
        letras_ingresadas[indice]=letra
 #     lista_palabra_secreta.remove(letra)
 #       print(lista_palabra_secreta)
      print(letras_ingresadas)
      longitud=longitud-palabra_secreta.count(letra)
 #      print(f'longitud: {longitud}') 
      


    else:
      print(f'''La letra "{letra}"" no está en la palabra secreta''')
      vidas=vidas-1
#*********************************************
      if entrada<=7:
        print(' ')
        print(ahorcado[entrada])
        entrada=entrada+1
#*********************************************
    
    
if vidas==0:
  print(f'''\n¡Lastima! se acabaron tus oportunidades la palabra era "{palabra_secreta}"''')
else:
  print(f'''\n¡Felicidades! lo lograste en {m} intentos, la palabra secreta es "{palabra_secreta}"''')



#longitud=len(palabra_secreta)-palabra_secreta.count(letra)
#print(f'longitud: {longitud}')
# Out:
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
# Bien venido al juego del ahorcado:
# = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#
# Adivina la palabra secreta:
# __ __ __ __ __  (5 letras)
#
# Te quedan 7 vidas.
#
# ------------------------------------------------
#
# Ingresa una letra (en minúscula): P
#
# La letra "p"" sí está en la palabra secreta y va colocada así:
#
# ['p', '_', '_', '_', '_']
#
# Te quedan 7 vidas.
#
# ------------------------------------------------
#
# Ingresa una letra (en minúscula): e
#
# La letra "e"" sí está en la palabra secreta y va colocada así:
#
# ['p', 'e', '_', '_', '_']
#
# Te quedan 7 vidas.
#
# ------------------------------------------------
#
# Ingresa una letra (en minúscula): r
#
# La letra "r"" sí está en la palabra secreta y va colocada así:
#
# ['p', 'e', 'r', 'r', '_']
#
# Te quedan 7 vidas.
#
# ------------------------------------------------
#
# Ingresa una letra (en minúscula): o
#
# ...

# %% [markdown]
# versión presentable
